# %%
import pandas as pd
import numpy as np
from scipy.signal import argrelextrema
from scipy.signal import find_peaks
from itertools import product
from tqdm import tqdm
import time
import numba as nb
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import talib as ta
from tqdm import tqdm

# %%
df=pd.read_csv('../EUR_USD_2020_M5.csv')

# %%
df.set_index('time',inplace=True)

# %%
class RSI_divergence():

    def __init__(self,data):

        self.data=data

        self.params_range={'window':[10,14,20,30],
                          'up_level':[60,70,80],
                          'down_level':[20,30,40]}

    def create_params_combs(self):

        return list(product(*self.params_range.values()))

# %%
rsid=RSI_divergence(df)

# %%
len(rsid.create_params_combs())
# Out:
# 36

# %%
df['RSI']=ta.RSI(df['c'],14)

# %%
df.iloc[50:100]
# Out:
#                                  o        h        l        c  volume  \
# time
# 2020-01-02 02:25:00+00:00  1.12204  1.12216  1.12202  1.12216      14
# 2020-01-02 02:30:00+00:00  1.12214  1.12222  1.12214  1.12222       8
# 2020-01-02 02:35:00+00:00  1.12224  1.12234  1.12224  1.12231       6
# 2020-01-02 02:40:00+00:00  1.12233  1.12239  1.12231  1.12239       9
# 2020-01-02 02:45:00+00:00  1.12242  1.12244  1.12242  1.12244       2
# 2020-01-02 02:50:00+00:00  1.12247  1.12247  1.12244  1.12244       4
# 2020-01-02 02:55:00+00:00  1.12242  1.12242  1.12220  1.12224      14
# 2020-01-02 03:00:00+00:00  1.12222  1.12227  1.12219  1.12227      11
# 2020-01-02 03:05:00+00:00  1.12229  1.12232  1.12229  1.12230       7
# 2020-01-02 03:10:00+00:00  1.12227  1.12227  1.12217  1.12217       5
# 2020-01-02 03:15:00+00:00  1.12215  1.12216  1.12193  1.12193      16
# 2020-01-02 03:20:00+00:00  1.12196  1.12198  1.12188  1.12196      11
# 2020-01-02 03:25:00+00:00  1.12198  1.12199  1.12182  1.12182      18
# 2020-01-02 03:30:00+00:00  1.12180  1.12180  1.12159  1.12164      23
# 2020-01-02 03:35:00+00:00  1.12162  1.12169  1.12160  1.12160      17
# 2020-01-02 03:40:00+00:00  1.12162  1.12162  1.12133  1.12138      26
# 2020-01-02 03:45:00+00:00  1.12136  1.12143  1.12133  1.12136      22
# 2020-01-02 03:50:00+00:00  1.12132  1.12133  1.12124  1.12132      11
# 2020-01-02 03:55:00+00:00  1.12135  1.12138  1.12130  1.12132       8
# 2020-01-02 04:00:00+00:00  1.12135  1.12135  1.12130  1.12133       6
# 2020-01-02 04:05:00+00:00  1.12130  1.12134  1.12126  1.12134      13
# 2020-01-02 04:10:00+00:00  1.12137  1.12142  1.12134  1.12142       9
# 2020-01-02 04:15:00+00:00  1.12140  1.12142  1.12140  1.12142       4
# 2020-01-02 04:20:00+00:00  1.12140  1.12140  1.12126  1.12128      10
# 2020-01-02 04:25:00+00:00  1.12126  1.12128  1.12120  1.12122       6
# 2020-01-02 04:30:00+00:00  1.12120  1.12121  1.12110  1.12119      21
# 2020-01-02 04:35:00+00:00  1.12116  1.12116  1.12108  1.12108      14
# 2020-01-02 04:40:00+00:00  1.12105  1.12107  1.12091  1.12098      16
# 2020-01-02 04:25:00+00:00      True  27.148948
# 2020-01-02 04:30:00+00:00      True  26.339124
# 2020-01-02 04:35:00+00:00      True  23.563654
# 2020-01-02 04:40:00+00:00      True  21.360069
# 2020-01-02 04:45:00+00:00      True  17.485871
# 2020-01-02 04:50:00+00:00      True  14.004394
# 2020-01-02 04:55:00+00:00      True  10.977983
# 2020-01-02 05:00:00+00:00      True  12.114286
# 2020-01-02 05:05:00+00:00      True  20.328150
# 2020-01-02 05:10:00+00:00      True  18.469222
# 2020-01-02 05:15:00+00:00      True  24.423462
# 2020-01-02 05:20:00+00:00      True  25.401305
# 2020-01-02 05:25:00+00:00      True  23.746893
# 2020-01-02 05:30:00+00:00      True  27.315606
# 2020-01-02 05:35:00+00:00      True  27.835203
# 2020-01-02 05:40:00+00:00      True  29.991076
# 2020-01-02 05:45:00+00:00      True  28.610382
# 2020-01-02 05:50:00+00:00      True  35.050526
# 2020-01-02 05:55:00+00:00      True  39.001235
# 2020-01-02 06:00:00+00:00      True  48.312384
# 2020-01-02 06:05:00+00:00      True  47.601022
# 2020-01-02 06:10:00+00:00      True  49.211706
# 2020-01-02 06:15:00+00:00      True  45.450310
# 2020-01-02 06:20:00+00:00      True  47.189107
# 2020-01-02 06:25:00+00:00      True  44.157482
# 2020-01-02 06:30:00+00:00      True  41.300092

# %%
def calc_div(window, close, rsi):

    min_close=close.iloc[0]
    max_close=close.iloc[0]

    min_rsi=rsi.iloc[0]
    max_rsi=rsi.iloc[0]

    for i in range(len(close)):

        if close.iloc[i]>=max_close:
            max_close=close[i]

        if close.iloc[i]<=min_close:
            min_close=close.iloc[i]

        
    return max_close, min_close

# %%
vals=df['c'].iloc[20:30]

# %%
vals
# Out:
# time
# 2020-01-01 23:55:00+00:00    1.12189
# 2020-01-02 00:00:00+00:00    1.12192
# 2020-01-02 00:05:00+00:00    1.12184
# 2020-01-02 00:10:00+00:00    1.12162
# 2020-01-02 00:15:00+00:00    1.12164
# 2020-01-02 00:20:00+00:00    1.12162
# 2020-01-02 00:25:00+00:00    1.12162
# 2020-01-02 00:30:00+00:00    1.12166
# 2020-01-02 00:35:00+00:00    1.12159
# 2020-01-02 00:40:00+00:00    1.12175
# Name: c, dtype: float64

# %%
slopes_vals=np.gradient(vals)

# %%
slopes_vals
# Out:
# array([ 3.0e-05, -2.5e-05, -1.5e-04, -1.0e-04,  0.0e+00, -1.0e-05,
#         2.0e-05, -1.5e-05,  4.5e-05,  1.6e-04])

# %%
np.sum(slopes_vals)
# Out:
# np.float64(-4.500000000007276e-05)

# %%
rsi=df['RSI'].iloc[20:30]

# %%
slopes_rsi=np.gradient(rsi)

# %%
np.sum(slopes_rsi)
# Out:
# np.float64(-4.44937258022426)

# %%
rsi
# Out:
# time
# 2020-01-01 23:55:00+00:00    64.674280
# 2020-01-02 00:00:00+00:00    65.673589
# 2020-01-02 00:05:00+00:00    60.739225
# 2020-01-02 00:10:00+00:00    49.683860
# 2020-01-02 00:15:00+00:00    50.564772
# 2020-01-02 00:20:00+00:00    49.629052
# 2020-01-02 00:25:00+00:00    49.629052
# 2020-01-02 00:30:00+00:00    51.702173
# 2020-01-02 00:35:00+00:00    47.980549
# 2020-01-02 00:40:00+00:00    55.810352
# Name: RSI, dtype: float64

# %%
calc_div(5, vals,[3,2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1
# 2020-01-02 04:00:00+00:00  1.12133  27.086091
# 2020-01-02 04:05:00+00:00  1.12134  27.766477
# 2020-01-02 04:10:00+00:00  1.12142  33.141456
# 2020-01-02 04:15:00+00:00  1.12142  33.141456
# 2020-01-02 04:20:00+00:00  1.12128  28.793024
# 2020-01-02 04:25:00+00:00  1.12122  27.148948
# 2020-01-02 04:30:00+00:00  1.12119  26.339124
# 2020-01-02 04:35:00+00:00  1.12108  23.563654
# 2020-01-02 04:40:00+00:00  1.12098  21.360069
# 2020-01-02 04:45:00+00:00  1.12076  17.485871
# 2020-01-02 04:50:00+00:00  1.12048  14.004394

# %%
st_df=scaler_st.fit_transform(rsi_vals)

# %%
scaler_mm=MinMaxScaler()

# %%
mm_df=scaler_mm.fit_transform(rsi_vals)

# %%
np.sum(np.gradient(rsi_vals['c'].iloc[:10]))
# Out:
# np.float64(0.00046500000000015973)

# %%
np.sum(np.gradient(rsi_vals['RSI'].iloc[:10]))
# Out:
# np.float64(7.6853712109998895)

# %%
np.sum(np.gradient(st_df['c'].iloc[:10]))
# Out:
# np.float64(0.9640645835711783)

# %%
np.sum(np.gradient(st_df['RSI'].iloc[:10]))
# Out:
# np.float64(0.45246094218974797)

# %%
np.sum(np.gradient(mm_df['c'].iloc[:10]))
# Out:
# np.float64(0.23724489795932868)

# %%
np.sum(np.gradient(mm_df['RSI'].iloc[:10]))
# Out:
# np.float64(0.13025401041729145)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity([rsi_vals['c'].iloc[:10]],[rsi_vals['RSI'].iloc[:10]])
# Out:
# array([[0.99686742]])

# %%
cosine_similarity([st_df['c'].iloc[:10]],[st_df['RSI'].iloc[:10]])
# Out:
# array([[0.93517362]])

# %%
cosine_similarity([mm_df['c'].iloc[:10]],[mm_df['RSI'].iloc[:10]])
# Out:
# array([[0.99901505]])

# %%
ar1=[6,2,3,4,3,4,5,2,1,3,5,6,7,8,9,10]
ar2=[6,2,1,3,4,5,6,4,3,2,1,4,5,4,3,2]

# %%
ar2=[val/10 for val in ar2]

# %%
ar2
# Out:
# [0.6,
#  0.2,
#  0.1,
#  0.3,
#  0.4,
#  0.5,
#  0.6,
#  0.4,
#  0.3,
#  0.2,
#  0.1,
#  0.4,
#  0.5,
#  0.4,
#  0.3,
#  0.2]

# %%
cosine_similarity([ar1],[ar2])
# Out:
# array([[0.83568799]])

# %%
np.sum(np.gradient(ar1))
# Out:
# np.float64(2.5)

# %%
np.sum(np.gradient(ar2))
# Out:
# np.float64(-6.5)

# %%
res
# Out:
# LinregressResult(slope=np.float64(0.008554216867469879), intercept=np.float64(0.30204819277108436), rvalue=np.float64(0.1414620524255654), pvalue=np.float64(0.601260657832978), stderr=np.float64(0.01599877647064744), intercept_stderr=np.float64(0.08799327058856092))

# %%
df_cos=df.iloc[1000:2000]

# %%
cossim=[]
for i in range(len(df_cos)):

    if i>=10:

        rsi_vals=df_cos.loc[:,['c','RSI']].iloc[i-10:i]
        cossimval=cosine_similarity([rsi_vals['c']],[rsi_vals['RSI']])
        cossim.append(cossimval[0][0])

    else:

        cossim.append(np.nan)

# %%
len(cossim)
# Out:
# 1000

# %%
df_cos['cossim']=cossim
# Out:
# C:\Users\sliso\AppData\Local\Temp\ipykernel_8096\2915257213.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#res = (a - a.min()) / (a.max() - a.min())
df_cos['cossim_norm']=(df_cos['cossim'] - df_cos['cossim'].min()) / (df_cos['cossim'].max() - df_cos['cossim'].min())
# Out:
# C:\Users\sliso\AppData\Local\Temp\ipykernel_8096\2465668785.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_cos
# Out:
#                                  o        h        l        c  volume  \
# time
# 2020-01-07 10:00:00+00:00  1.11847  1.11860  1.11810  1.11826     100
# 2020-01-07 10:05:00+00:00  1.11824  1.11828  1.11816  1.11824      64
# 2020-01-07 10:10:00+00:00  1.11822  1.11840  1.11816  1.11838      40
# 2020-01-07 10:15:00+00:00  1.11840  1.11858  1.11733  1.11752     127
# 2020-01-07 10:20:00+00:00  1.11755  1.11782  1.11692  1.11697     153
# ...                            ...      ...      ...      ...     ...
# 2020-01-10 21:10:00+00:00  1.11218  1.11218  1.11206  1.11206      12
# 2020-01-10 21:15:00+00:00  1.11208  1.11214  1.11206  1.11212      10
# 2020-01-10 21:20:00+00:00  1.11214  1.11214  1.11202  1.11202       6
# 2020-01-10 21:30:00+00:00  1.11204  1.11211  1.11204  1.11211       8
# 2020-01-10 21:35:00+00:00  1.11213  1.11216  1.11211  1.11213       5
#
#                            complete        RSI    cossim  cossim_norm
# time
# 2020-01-07 10:00:00+00:00      True  48.757009       NaN          NaN
# 2020-01-07 10:05:00+00:00      True  48.323379       NaN          NaN
# 2020-01-07 10:10:00+00:00      True  51.570334       NaN          NaN
# 2020-01-07 10:15:00+00:00      True  36.428496       NaN          NaN
# 2020-01-07 10:20:00+00:00      True  30.300982       NaN          NaN
# ...                             ...        ...       ...          ...
# 2020-01-10 21:10:00+00:00      True  48.598859  0.998295     0.959607
# 2020-01-10 21:15:00+00:00      True  51.660825  0.998059     0.952642
# 2020-01-10 21:20:00+00:00      True  46.670764  0.998342     0.960994
# 2020-01-10 21:30:00+00:00      True  51.236075  0.998058     0.952626
# 2020-01-10 21:35:00+00:00      True  52.215042  0.998041     0.952109
#
# [1000 rows x 9 columns]

# %%
figure = make_subplots(rows=3, cols=1, row_heights=[0.5,0.25,0.25], shared_xaxes=True,vertical_spacing=0.01)
figure.update_layout(height=800, width=1200, title_text='pos_ch_retr_0.382_per_20')


figure.add_trace(go.Candlestick(x=df_cos.index,
                                open=df_cos['o'],
                                high=df_cos['h'],
                                low=df_cos['l'],
                                close=df_cos['c'],
                                name='price'), row=1, col=1)
figure.add_trace(go.Scatter(x=df_cos.index,y=df_cos['RSI'],mode='lines',line_color='blue',name='cossim'),col=1,row=2 )
figure.add_trace(go.Scatter(x=df_cos.index,y=df_cos['cossim_norm'],mode='lines',line_color='yellow',name='cossim'),col=1,row=3 )
figure.add_hline(y=0.7, col=1,row=3)

figure.update_layout(xaxis_rangeslider_visible=False)
figure.update_xaxes(
        rangebreaks=[
            dict(bounds=["sat", "mon"])]
    )
figure.show()
